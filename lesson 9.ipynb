# %%
data_points = [(1, 4), (2, 5),(3, 6)]
type(data_points)
# Out:
# list

# %%
data_points[0]=(4,7)
data_points
# Out:
# [(4, 7), (2, 5), (3, 6)]

# %%
elem = (1,4)
type(elem)
elem[0]
# Out:
# 1

# %%
data_points = [(1, 4), (2, 5),(3, 6)]
for pnt in data_points:
    print(pnt)
    #print(pnt[0])
# Out:
# (1, 4)
# (2, 5)
# (3, 6)

# %%
data_points = [(1, 4), (2, 5),(3, 6)]
points = []
X=[]
for pnt in data_points:
    points.append(pnt)
    X.append(pnt[0])
print(points)
print(X)
type(points)
# Out:
# [(1, 4), (2, 5), (3, 6)]
# [1, 2, 3]
# list

# %%
"""flowchart symbol: https://www.zenflowchart.com/flowchart-symbols"""
# Out:
# 'flowchart symbol: https://www.zenflowchart.com/flowchart-symbols'

# %%
import requests

# URL of the image
url = 'https://automatetheboringstuff.com/images/000102.png'

# Send a request to the URL and download the image
image = requests.get(url)

# Save the image locally
with open('flowchart_for.png', 'wb') as file:
    file.write(image.content)
"""citation: https://automatetheboringstuff.com/chapter2/"""
# Out:
# 'citation: https://automatetheboringstuff.com/chapter2/'

# %%
from PIL import Image
from IPython.display import display

# Open the image using PIL
img_for = Image.open('flowchart_for.png')

# Display the image
display(img_for)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=630x503>

# %%
# code for the for loop flowchart
print('My name is')
for i in range(5):
    print('Jimmy Five Times (' + str(i) + ')')
# Out:
# My name is
# Jimmy Five Times (0)
# Jimmy Five Times (1)
# Jimmy Five Times (2)
# Jimmy Five Times (3)
# Jimmy Five Times (4)

# %%
# try flowchart
data_points = [(1, 4), (2, 5),(3, 6)]
for pnt in data_points:
    print(pnt)

# %%
from PIL import Image
from IPython.display import display

# Open the image using PIL
img_for = Image.open("for loop flct ex1.png")

# Display the image
display(img_for)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1378x1240>

# %%
# from another angle
data_points[0][0]

for i in range(3):
    x = data_points[i][0]
    y = data_points[i][1]
    print("x=",x)
    print("y=",y)
# Out:
# x= 1
# y= 4
# x= 2
# y= 5
# x= 3
# y= 6

# %%
x=[]
y=[]
for i in range(3):
    x.append(data_points[i][0])
    y.append(data_points[i][1])
print("x=",x)
print("y=",y)
# Out:
# x= [1, 2, 3]
# y= [4, 5, 6]

# %%
# Open the image using PIL
img_for = Image.open("for loop flct ex2.png")

# Display the image
display(img_for)
"""the key point is: do not add any more step after the END, because this is THE END"""
"""END FOR LOOP is optional, but if you want to show the loop clearly, add the END FOR beside the FOR box"""
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1406x1814>

# %%
# Open the image using PIL
img_for = Image.open("flct_forloop_in_words.png")

# Display the image
display(img_for)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1584x1732>

# %%
# Open the image using PIL
img_smb = Image.open("flowchart symbols.png")

# Display the image
display(img_smb)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=800x528>

# %%
url_if = 'https://www.visual-paradigm.com/servlet/editor-content/tutorials/flowchart-tutorial/sites/7/2018/09/flowchart-example-calculate-profit-and-loss.png'
image = requests.get(url_if)

# Save the image locally
with open('flowchart_if.png', 'wb') as file:
    file.write(image.content)

# Open the image using PIL
img_if = Image.open('flowchart_if.png')

# Display the image
display(img_if)

print("citation: https://www.visual-paradigm.com/tutorials/flowchart-tutorial/")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=649x611>
# citation: https://www.visual-paradigm.com/tutorials/flowchart-tutorial/

# %%
grade = int(input("Enter your grade (0-100): "))

if grade >= 60:
    letter_grade = 'Pass'
else:
    letter_grade = 'Fail'

print("Your letter grade is:", letter_grade)
# Out:
# Your letter grade is: Pass

# %%
# Open the image using PIL
img_if = Image.open("flowchart_if_ex1.png")

# Display the image
display(img_if)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=992x1700>

# %%
# linear regression
# Slope (m) = (Σ((x - x_mean) * (y - y_mean))) / (Σ((x - x_mean)^2))
#  x - x_mean : This calculates how far each x-value is from the mean of x. This gives us a measure of deviation from the mean.
# so does y - y_mean
"""The Numerator: (Σ((x - x_mean) * (y - y_mean))), is covariance: calculates the sum of the products of deviations from the mean for both x and y.
 This essentially captures how changes in x are associated with changes in y."""
"""The denominator (Σ((x - x_mean)^2)) represents the total variability in  x , 
but it is not explicitly labeled as variance since we are not dividing it by  n  or  n-1  in this context."""
# n-1  is known as Bessel's correction.
"""
SLOPE = Cov(x,y)/Var(x), is the ratio of covariance to variance. 
It represents how much  y  changes for a one-unit increase in  x .
"""
"""so voc(x,y) divided by var(x) is to show the magnitude or how much y changes with x"""

"""note: you need to use calculate like:
[(x1-x_mean)*(y1-y_mean) + (x2-x_mean)*(y2-y_mean) + (x3-x_mean)*(y3-y_mean) +...+ (xn-x_mean)*(yn-y_mean)] / [(x1-x_mean)^2 + (x2-x_mean)^2 + (x3-x_mean)^2 +...+ (xn-x_mean)^2]"""
